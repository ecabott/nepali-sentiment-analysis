# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
# Read in data
df = pd.read_csv('./input/social-media-comments/comments.csv')
print(df.shape)
df = df.head(500)
print(df.shape)
# Out:
# (6000, 2)
# (500, 2)

# %%
df.head()
# Out:
#                                                 text label
# 0  बजार ले जसरी ट्रेन्ड चेन्ज गर्यो यो हेर्दा तत्...     2
# 1  1000 अंकले घटेको नेप्से 200 अंकले बढ्नु ठूलो क...     1
# 2  होइन यो सानिमा बैंक ले bonus घोसणा गरेको २ महि...     2
# 3  खैँ MBJC प्रति कित्तामा रू,10/-ले बढेर आज रू,1...     2
# 4                                       राम्रो भयो️️     1

# %% [markdown]
# # Quick EDA

# %%
df['label'].value_counts().sort_index().plot(kind='bar', title='Count of Label', figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Count of Label'}, xlabel='label'>

# %% [markdown]
# ## Basic NLTK

# %%
example = df['text'][50]
print(example)
# Out:
# चोरले म चोर हुँ कदापि भन्दैन लाज पचेको ७० करोड वलिको पुच्छरको चुरिफुरी देख्दा उदेक लाग्छ
